# %% [markdown]
# <h1><b>Assignment 3</b></h1>
# <ul>
#     <li><u>Mauricio Mendez Ruiz</u>: A00812794</li>
#     <li><u>Carlos Flores Munguia</u>: A00831376</li>
#     <li><u>Hernan Espinosa Rodriguez</u>: A01112132</li>
# <ul>

# %% [markdown]
# In this assignment we solve the CleanUp Puzzle formulating it as a simple state problem to be solved by a problem-solving agent (PSA), then solving it by using selected uninformed search methods.
#
# The first step is to initialize all the libraries which will be using during the execution of the algorithm.

# %%
# !pip install ipythonblocks

#We import all the necessary libraries.
from ipythonblocks import BlockGrid
from agents import *

from search import ( # Bases for problem building
    Problem, Node, Graph, UndirectedGraph,
    SimpleProblemSolvingAgentProgram,
    GraphProblem
)

from search import ( # Uninformed search algorithms
    tree_search, graph_search, best_first_graph_search,
    breadth_first_tree_search, breadth_first_search,
    depth_first_tree_search, depth_first_graph_search,
    depth_limited_search, iterative_deepening_search,
    uniform_cost_search,
    compare_searchers
)

from search import ( # Informed search algorithms
    greedy_best_first_graph_search, astar_search
)
# Out:
# Requirement already satisfied: ipythonblocks in c:\users\carlo\appdata\local\programs\python\python38\lib\site-packages (1.9.0)
# Requirement already satisfied: ipython>=4.0 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from ipythonblocks) (7.18.1)
# Requirement already satisfied: notebook>=4.0 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from ipythonblocks) (6.1.3)
# Requirement already satisfied: requests>=1.0 in c:\users\carlo\appdata\local\programs\python\python38\lib\site-packages (from ipythonblocks) (2.24.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from ipython>=4.0->ipythonblocks) (3.0.7)
# Requirement already satisfied: traitlets>=4.2 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from ipython>=4.0->ipythonblocks) (5.0.4)
# Requirement already satisfied: decorator in c:\users\carlo\appdata\local\programs\python\python38\lib\site-packages (from ipython>=4.0->ipythonblocks) (4.4.2)
# Requirement already satisfied: pickleshare in c:\users\carlo\appdata\roaming\python\python38\site-packages (from ipython>=4.0->ipythonblocks) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\carlo\appdata\local\programs\python\python38\lib\site-packages (from ipython>=4.0->ipythonblocks) (47.1.0)
# Requirement already satisfied: backcall in c:\users\carlo\appdata\roaming\python\python38\site-packages (from ipython>=4.0->ipythonblocks) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from ipython>=4.0->ipythonblocks) (0.17.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\carlo\appdata\roaming\python\python38\site-packages (from ipython>=4.0->ipythonblocks) (0.4.3)
# Requirement already satisfied: pygments in c:\users\carlo\appdata\roaming\python\python38\site-packages (from ipython>=4.0->ipythonblocks) (2.6.1)
# Requirement already satisfied: nbconvert in c:\users\carlo\appdata\roaming\python\python38\site-packages (from notebook>=4.0->ipythonblocks) (5.6.1)
# Requirement already satisfied: ipython-genutils in c:\users\carlo\appdata\roaming\python\python38\site-packages (from notebook>=4.0->ipythonblocks) (0.2.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from notebook>=4.0->ipythonblocks) (0.8.3)
# Requirement already satisfied: ipykernel in c:\users\carlo\appdata\roaming\python\python38\site-packages (from notebook>=4.0->ipythonblocks) (5.3.4)
# Requirement already satisfied: tornado>=5.0 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from notebook>=4.0->ipythonblocks) (6.0.4)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from notebook>=4.0->ipythonblocks) (4.6.3)
# Requirement already satisfied: Send2Trash in c:\users\carlo\appdata\roaming\python\python38\site-packages (from notebook>=4.0->ipythonblocks) (1.5.0)
# Requirement already satisfied: nbformat in c:\users\carlo\appdata\roaming\python\python38\site-packages (from notebook>=4.0->ipythonblocks) (5.0.7)
# Requirement already satisfied: pyzmq>=17 in c:\users\carlo\appdata\local\programs\python\python38\lib\site-packages (from notebook>=4.0->ipythonblocks) (19.0.2)
# Requirement already satisfied: jinja2 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from notebook>=4.0->ipythonblocks) (2.11.2)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from notebook>=4.0->ipythonblocks) (6.1.7)
# Requirement already satisfied: prometheus-client in c:\users\carlo\appdata\roaming\python\python38\site-packages (from notebook>=4.0->ipythonblocks) (0.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\carlo\appdata\roaming\python\python38\site-packages (from notebook>=4.0->ipythonblocks) (20.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\carlo\appdata\local\programs\python\python38\lib\site-packages (from requests>=1.0->ipythonblocks) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\carlo\appdata\local\programs\python\python38\lib\site-packages (from requests>=1.0->ipythonblocks) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\carlo\appdata\local\programs\python\python38\lib\site-packages (from requests>=1.0->ipythonblocks) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\carlo\appdata\local\programs\python\python38\lib\site-packages (from requests>=1.0->ipythonblocks) (3.0.4)
# Requirement already satisfied: wcwidth in c:\users\carlo\appdata\roaming\python\python38\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0->ipythonblocks) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from jedi>=0.10->ipython>=4.0->ipythonblocks) (0.7.1)
# Requirement already satisfied: defusedxml in c:\users\carlo\appdata\roaming\python\python38\site-packages (from nbconvert->notebook>=4.0->ipythonblocks) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from nbconvert->notebook>=4.0->ipythonblocks) (1.4.2)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from nbconvert->notebook>=4.0->ipythonblocks) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from nbconvert->notebook>=4.0->ipythonblocks) (0.8.4)
# Requirement already satisfied: bleach in c:\users\carlo\appdata\roaming\python\python38\site-packages (from nbconvert->notebook>=4.0->ipythonblocks) (3.1.5)
# Requirement already satisfied: testpath in c:\users\carlo\appdata\roaming\python\python38\site-packages (from nbconvert->notebook>=4.0->ipythonblocks) (0.4.4)
# Requirement already satisfied: pywinpty>=0.5; os_name == "nt" in c:\users\carlo\appdata\roaming\python\python38\site-packages (from terminado>=0.8.3->notebook>=4.0->ipythonblocks) (0.5.7)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\carlo\appdata\roaming\python\python38\site-packages (from jupyter-core>=4.6.1->notebook>=4.0->ipythonblocks) (228)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from nbformat->notebook>=4.0->ipythonblocks) (3.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from jinja2->notebook>=4.0->ipythonblocks) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\carlo\appdata\local\programs\python\python38\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.0->ipythonblocks) (2.8.1)
# Requirement already satisfied: six in c:\users\carlo\appdata\local\programs\python\python38\lib\site-packages (from argon2-cffi->notebook>=4.0->ipythonblocks) (1.15.0)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from argon2-cffi->notebook>=4.0->ipythonblocks) (1.14.2)
# Requirement already satisfied: packaging in c:\users\carlo\appdata\roaming\python\python38\site-packages (from bleach->nbconvert->notebook>=4.0->ipythonblocks) (20.4)
# Requirement already satisfied: webencodings in c:\users\carlo\appdata\roaming\python\python38\site-packages (from bleach->nbconvert->notebook>=4.0->ipythonblocks) (0.5.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.0->ipythonblocks) (0.16.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\carlo\appdata\roaming\python\python38\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.0->ipythonblocks) (20.2.0)
# Requirement already satisfied: pycparser in c:\users\carlo\appdata\roaming\python\python38\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.0->ipythonblocks) (2.20)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\carlo\appdata\local\programs\python\python38\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.0->ipythonblocks) (2.4.7)
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the 'c:\users\carlo\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# <h1>Environment:</h1>
#
# This environment was declared to show the cleanup board's state in every step until solve the problem.

# %%
class Ball(Thing):
    pass

class Click(Thing):
    pass

#We define the environment class
class CleanupPuzzleEnvironment(Environment):
    def __init__(self, width=5, height=5):
        #We define the main characteristics of the environment. Among them, the color of the empty cells,
        #the size of the grid, and the color of the balls.
        super(CleanupPuzzleEnvironment, self).__init__()
        self.width = width
        self.height = height

        self.bg_color = (207, 216, 220)
        self.ball_color = (0, 191, 165)
        self.click_color = (244, 67, 54)
        self.grid = BlockGrid(width, height, fill=self.bg_color)

    def __str__(self):
        #We display the initial grid grid.
        world = self.get_world()
        self.draw_grid(world)
        self.grid.show()
        return ''

    def draw_grid(self, world):
        #We build the displayable grid, by showing first the grid as empty.
        #We then proceed to check all the spaces of the grid, to fill it with either clicks, balls, or leaving
        #the space empty
        self.grid[:] = self.bg_color
        for x in range(0, len(world)):
            for y in range(0, len(world[x])):
                if len(world[x][y]) and isinstance(world[x][y][0], Ball):
                    self.grid[x, y] = self.ball_color
                elif len(world[x][y]) and isinstance(world[x][y][0], Click):
                    self.grid[x, y] = self.click_color

    def get_world(self):
        #Returns the items that are in the world at the moment
        result = []
        for x in range(self.height):
            row = []
            for y in range(self.width):
                row.append(self.list_things_at((x, y)))
            result.append(row)
        return result

    def is_inbounds(self, location):
        #Checks that the location selected is inside the boundaries of the problem.
        x,y = location
        return not (x < 0 or x >= self.height or y < 0 or y >= self.width)

# %% [markdown]
# # Problem
#
# The class called CleanBoardProblem is derived from the Problem class where we initialize the initial and the goal state, while also including the size of the board.
#
# Some of the methods that we need to define in order to solve a particular problems are:
# <ul>
#     <li>actions(): </li> According to the problem in every state, we need to get a list of actions that could be performed following the rules of the game.
#     <li>result(): </li> It gives us the resulting new state after applying the action that is described in the parameters.
#     <li>goal_test(): </li> Checks if the current state is equal to the goal state, and ends the method if the goal state is reached.
#     <li>path_cost: </li> Adds cost to move from the actual state to the following state.
#
# </ul>

# %%
class CleanBoardProblem(Problem):
    #We define the base problem
    def __init__(self, initial=[], goal=[], size=5):
        Problem.__init__(self, initial, goal)
        self.size = size

    def actions(self, state):
        #We get a list of all the actions that could be performed by the agent, and what areas of the grid it affects.
        action_coords = []

        for (x, y) in state:
            near_locations = [(x-1, y), (x+1, y), (x,y-1), (x, y+1)]
            for loc in near_locations:
                if self.is_inbounds(loc) and loc not in state and loc not in action_coords:
                    action_coords.append(loc)

        sorted_list = sorted(action_coords, key=lambda x: [x[0], x[1]])
        return tuple(sorted_list)

    def result(self, state, action):
        #We get the resulting states that could be obtained from the actions performed by the action.
        x, y = action
        near_locations = [(x-1, y), (x+1, y), (x,y-1), (x, y+1)]

        new_state = [e for e in state]
        for loc in near_locations:
            if self.is_inbounds(loc) and loc not in new_state:
                new_state.append(loc)
            elif self.is_inbounds(loc) and loc in new_state:
                new_state.remove(loc)

        sorted_list = sorted(new_state, key=lambda x: [x[0], x[1]])
        return tuple(sorted_list)

    def goal_test(self, state):
        #Check the current state to determine if we have reached the goal.
        if len(state) < 1:
            return True
        return False

    #We get the cost of each of the actions and add them together.
    def path_cost(self, c, state1, action, state2):
        diff = len(state2) - len(state1)
        return c + diff

    def is_inbounds(self, location):
        #Check that the actions do not affect out of bound parts of the grid.
        x,y = location
        return not (x < 0 or x >= self.size or y < 0 or y >= self.size)

# %% [markdown]
# # Visualization Functions
# The display_solution() function is declared to print the path followed by the search method until the problem is solved. At every step it shows the cells were balls are allocated, and where the click has been made by the agent

# %%
def display_solution(solution, initial_state, size):
    #We print the non-solution result. The case were the agent cant reach a solution.
    if not solution:
        print("Failure: no solution found")
        return

    #We print the initial state of the problem.
    print('Initial State:')
    environment = CleanupPuzzleEnvironment(size, size)
    for loc in initial_state:
        ball = Ball()
        environment.add_thing(ball, loc)
    print(environment)

    #We print all the subsequent steps, until we reach the final state.
    i = 0
    path = solution.path()
    for p in path:
        print('Step %s:' % (i+1))
        environment = CleanupPuzzleEnvironment(size, size)

        sol = solution.solution()
        if i < len(sol):
            click = Click()
            environment.add_thing(click, sol[i])

        for loc in p.state:
            ball = Ball()
            environment.add_thing(ball, loc)
        
        print(environment)
        print('')
        i += 1

# %% [markdown]
# # Tests
# In this section we create a new Cleanup Puzzle problem, which is an <b><u>easy</u></b> 5x5 board, in order to solve it using different search methods. Here we show the board and the balls in their position:

# %%
#We set up the initial state of the problem. We accomodate the initial position of the balls.
# [(ROW,COLUMN)]
initial_state = tuple([(0,0), (1,1), (2,0), (3,3), (4,2), (4,4)])
size = 5

environment = CleanupPuzzleEnvironment(size, size)

for s in initial_state:
    ball = Ball()
    environment.add_thing(ball, s)

print(environment)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blockse501fe24-c77a-45ef-9851-2eae4105726c td {border: 1px solid white;}</style><table id="blockse501fe24-c77a-45ef-9851-2eae4105726c" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>

# %% [markdown]
# In the following cells you can see the steps followed to reach a state where the board is clean of balls.
#
# <u>Using Breadth First Search</u>

# %%
import time

#We sort the position of the balls in the grid. This is for the purpose of correct display.
initial_state = sorted(initial_state, key=lambda x: [x[0], x[1]])
initial_state = tuple(initial_state)

problem = CleanBoardProblem(initial_state, [], size) #We call the method that defines the initial state.
start_time_bfs = time.time() #We initialize the time metric for our search algorithm
goalBFS = breadth_first_search(problem) #We initialize the agent performing a BFS algorithm
end_time_bfs = time.time() - start_time_bfs #We calculate the time it took the algorithm to solve the problem.

#We display the solution of the initial problem
display_solution(goalBFS, initial_state, size)
# Out:
# Initial State:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks6a39320d-2745-41eb-9566-cd8d4e9c888a td {border: 1px solid white;}</style><table id="blocks6a39320d-2745-41eb-9566-cd8d4e9c888a" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 1:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks0696da7d-2eb1-48cd-81ec-584ef3441dc1 td {border: 1px solid white;}</style><table id="blocks0696da7d-2eb1-48cd-81ec-584ef3441dc1" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 2:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks04ef1cbf-434d-4511-88c1-1fd0d6bed1a1 td {border: 1px solid white;}</style><table id="blocks04ef1cbf-434d-4511-88c1-1fd0d6bed1a1" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 3:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks61787ee3-25ab-42c2-be70-c5d26b782196 td {border: 1px solid white;}</style><table id="blocks61787ee3-25ab-42c2-be70-c5d26b782196" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr></tbody></table>

# %% [markdown]
# <u>Using Depth First Search (with graph)</u>

# %%
start_time_dfs = time.time() #We initialize the time metric for our search algorithm
goalDFS = depth_first_graph_search(problem) #We initialize the agent performing a BFS algorithm
end_time_dfs = time.time() - start_time_dfs #We calculate the time it took the algorithm to solve the problem.

#We display the solution of the initial problem
display_solution(goalDFS, initial_state, size)
# Out:
# Initial State:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks351f8b1f-72c8-4845-8d26-e9adb4067f3d td {border: 1px solid white;}</style><table id="blocks351f8b1f-72c8-4845-8d26-e9adb4067f3d" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 1:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blockse01a8094-005e-450f-aa2c-872f75fd3d9c td {border: 1px solid white;}</style><table id="blockse01a8094-005e-450f-aa2c-872f75fd3d9c" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 2:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks4322f918-28a5-40ec-a541-32089cd48790 td {border: 1px solid white;}</style><table id="blocks4322f918-28a5-40ec-a541-32089cd48790" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr></tbody></table>
# Step 3:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks5f0cf6bd-98e0-48ac-9cb1-8728d8eb51d0 td {border: 1px solid white;}</style><table id="blocks5f0cf6bd-98e0-48ac-9cb1-8728d8eb51d0" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr></tbody></table>

# %% [markdown]
# <u>Using Uniform Cost Search</u>

# %%
start_time_ucs = time.time() #We initialize the time metric for our search algorithm
goalUCS = uniform_cost_search(problem) #We initialize the agent performing a BFS algorithm
end_time_ucs = time.time() - start_time_ucs #We calculate the time it took the algorithm to solve the problem.

#We display the solution of the initial problem
display_solution(goalUCS, initial_state, size)
# Out:
# Initial State:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksa2459bee-248d-4af4-961d-7fa0d8468f30 td {border: 1px solid white;}</style><table id="blocksa2459bee-248d-4af4-961d-7fa0d8468f30" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 1:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks47450778-1ff1-47a0-b7f2-4b3ac2c96621 td {border: 1px solid white;}</style><table id="blocks47450778-1ff1-47a0-b7f2-4b3ac2c96621" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 2:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks8b79cc5f-7a4f-4cba-a74f-3eb237aa2614 td {border: 1px solid white;}</style><table id="blocks8b79cc5f-7a4f-4cba-a74f-3eb237aa2614" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr></tbody></table>
# Step 3:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks9ea869b3-1935-4e35-9e4e-789a5753400a td {border: 1px solid white;}</style><table id="blocks9ea869b3-1935-4e35-9e4e-789a5753400a" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr></tbody></table>

# %% [markdown]
# <u>Using Depth Limited Search</u>

# %%
start_time_dls = time.time() #We initialize the time metric for our search algorithm
goalDLS = depth_limited_search(problem) #We initialize the agent performing a BFS algorithm
end_time_dls = time.time() - start_time_dls #We calculate the time it took the algorithm to solve the problem.

#We display the solution of the initial problem
display_solution(goalDLS, initial_state, size)
# Out:
# Initial State:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks4ac35aa6-f78a-4fef-8065-c5f14fa67226 td {border: 1px solid white;}</style><table id="blocks4ac35aa6-f78a-4fef-8065-c5f14fa67226" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 1:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks4df87fff-2adc-4992-b696-2a674a462d47 td {border: 1px solid white;}</style><table id="blocks4df87fff-2adc-4992-b696-2a674a462d47" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 2:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks57910450-3a2f-4868-bc55-94b7e6732cf0 td {border: 1px solid white;}</style><table id="blocks57910450-3a2f-4868-bc55-94b7e6732cf0" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 1]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [0, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 3:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks7808b39d-9b4a-4b7a-9ad4-c55b829503ca td {border: 1px solid white;}</style><table id="blocks7808b39d-9b4a-4b7a-9ad4-c55b829503ca" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 4:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks90069334-dbb4-48ea-92e9-867acf24610f td {border: 1px solid white;}</style><table id="blocks90069334-dbb4-48ea-92e9-867acf24610f" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 1]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [0, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 5:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks1746828d-b0c0-415a-85f6-ece285e2ff60 td {border: 1px solid white;}</style><table id="blocks1746828d-b0c0-415a-85f6-ece285e2ff60" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 6:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksfe5ff95a-8838-4d3a-9097-3e8f63f74e99 td {border: 1px solid white;}</style><table id="blocksfe5ff95a-8838-4d3a-9097-3e8f63f74e99" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 1]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [0, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 7:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks56f09bf4-7a53-4ed3-beb0-30281fa9d776 td {border: 1px solid white;}</style><table id="blocks56f09bf4-7a53-4ed3-beb0-30281fa9d776" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 8:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks6858b5e3-32ab-490b-9bb7-e521c098c051 td {border: 1px solid white;}</style><table id="blocks6858b5e3-32ab-490b-9bb7-e521c098c051" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 1]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [0, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 9:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks18315844-779f-4f63-8416-966894eb127b td {border: 1px solid white;}</style><table id="blocks18315844-779f-4f63-8416-966894eb127b" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 10:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks25e558b9-27bc-4bf7-8c2f-bb72f19e361c td {border: 1px solid white;}</style><table id="blocks25e558b9-27bc-4bf7-8c2f-bb72f19e361c" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 1]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [0, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 11:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks93af8313-b884-416a-a491-12259bc5d7f0 td {border: 1px solid white;}</style><table id="blocks93af8313-b884-416a-a491-12259bc5d7f0" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 12:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks089136ef-5d17-417e-9d19-df953f9a7147 td {border: 1px solid white;}</style><table id="blocks089136ef-5d17-417e-9d19-df953f9a7147" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 1]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [0, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 13:
# ...
# Step 48:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks390860cf-8c36-40e4-90c3-792890863f7c td {border: 1px solid white;}</style><table id="blocks390860cf-8c36-40e4-90c3-792890863f7c" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 1]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [0, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 49:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksb2220b8a-c1f2-4f88-8106-02b80f9b45e7 td {border: 1px solid white;}</style><table id="blocksb2220b8a-c1f2-4f88-8106-02b80f9b45e7" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 50:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blockse2f39a00-c9cf-4ce4-a5c8-363d375b73fc td {border: 1px solid white;}</style><table id="blockse2f39a00-c9cf-4ce4-a5c8-363d375b73fc" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 51:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks406a409a-8774-45d9-b912-1a0b11047203 td {border: 1px solid white;}</style><table id="blocks406a409a-8774-45d9-b912-1a0b11047203" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr></tbody></table>

# %% [markdown]
# <u>Using Iterative Deepening Search</u>

# %%
start_time_ids = time.time() #We initialize the time metric for our search algorithm
goalIDS = iterative_deepening_search(problem) #We initialize the agent performing a BFS algorithm
end_time_ids = time.time() - start_time_ids #We calculate the time it took the algorithm to solve the problem.

#We display the solution of the initial problem
display_solution(goalIDS, initial_state, size)
# Out:
# Initial State:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks001dbd85-6239-4b76-9b97-fe3ac4d1579f td {border: 1px solid white;}</style><table id="blocks001dbd85-6239-4b76-9b97-fe3ac4d1579f" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 1:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks4af69ef7-7362-462c-a736-46e5557ec925 td {border: 1px solid white;}</style><table id="blocks4af69ef7-7362-462c-a736-46e5557ec925" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [1, 1]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 2:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks133265b3-4648-4c70-bfc6-9053917602c6 td {border: 1px solid white;}</style><table id="blocks133265b3-4648-4c70-bfc6-9053917602c6" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td><td title="Index: [4, 3]&#10;Color: (244, 67, 54)" style="width: 20px; height: 20px;background-color: rgb(244, 67, 54);"></td><td title="Index: [4, 4]&#10;Color: (0, 191, 165)" style="width: 20px; height: 20px;background-color: rgb(0, 191, 165);"></td></tr></tbody></table>
# Step 3:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksbc7d25e9-da37-4222-b81f-99424f97f6f2 td {border: 1px solid white;}</style><table id="blocksbc7d25e9-da37-4222-b81f-99424f97f6f2" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [0, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [1, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [2, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [3, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr><tr><td title="Index: [4, 0]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 1]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 2]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 3]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td><td title="Index: [4, 4]&#10;Color: (207, 216, 220)" style="width: 20px; height: 20px;background-color: rgb(207, 216, 220);"></td></tr></tbody></table>

# %% [markdown]
# # Some Metrics

# %% [markdown]
# This bar graph represents the total time taken by each search method to solve the problem. The less time they took, the better.

# %%
import matplotlib.pyplot as plt

searchMethods = ['Breadth First Search', 'Depth First Graph Search', 'Uniform Cost Search', 'Depth Limited Search', 'Iterative Deepening Search']
timeToExecute = [end_time_bfs,end_time_dfs,end_time_ucs,end_time_dls,end_time_ids]

plt.barh(searchMethods,timeToExecute)
plt.xticks(rotation=90)
plt.title('Time to find the solution by seach methods (lower is better)')
plt.show()

# %% [markdown]
# Now, we present the total number of clicks on the board made by each search method until solve the problem.

# %%
searchMethods = ['Breadth First Search', 'Depth First Graph Search', 'Uniform Cost Search', 'Depth Limited Search', 'Iterative Deepening Search']

goalBFS = breadth_first_search(problem)
# goalDFS = depth_first_graph_search(problem)
# goalUCS = uniform_cost_search(problem)
# goalDLS = depth_limited_search(problem)
# goalIDS = iterative_deepening_search(problem)

numberOfClicks = [
        len(goalBFS.solution()),
        len(goalDFS.solution()),
        len(goalUCS.solution()),
        len(goalDLS.solution()),
        len(goalIDS.solution())
    ]

plt.bar(searchMethods,numberOfClicks)
plt.xticks(rotation=90)
plt.title('# click to find the solution by seach methods (lower is better)')
plt.show()

# %% [markdown]
# Finally, these graphs represents how the number of balls on the board was changing at every click.

# %%
import numpy as np

# BFS
ballsLeftBFS = []
for i in range(len(goalBFS.solution())):
    ballsLeftBFS.append(len(goalBFS.path()[i].state))
ballsLeftBFS.append(0)

clicksBFS = np.arange(0,len(goalBFS.path()), 1)

plt.xlabel('Click number')
plt.xlabel('Balls left')
plt.title('Evolution of balls left over clicks for BFS')
plt.plot(clicksBFS, ballsLeftBFS)
plt.scatter(clicksBFS, ballsLeftBFS, c='r')

# plt.xlabel('Click number')
# plt.xlabel('Balls left')
# plt.title('Evolution of balls left over clicks')
# plt.plot(clicks, ballsLeft)
# plt.scatter(clicks, ballsLeft, c='r')

# %%
# DFS
ballsLeftDFS = []
for i in range(len(goalDFS.solution())):
    ballsLeftDFS.append(len(goalDFS.path()[i].state))
ballsLeftDFS.append(0)

clicksDFS = np.arange(0,len(goalDFS.path()), 1)

plt.xlabel('Click number')
plt.xlabel('Balls left')
plt.title('Evolution of balls left over clicks for DFS')
plt.plot(clicksDFS, ballsLeftDFS)
plt.scatter(clicksDFS, ballsLeftDFS, c='r')

# %%
# UCS
ballsLeftUCS = []
for i in range(len(goalUCS.solution())):
    ballsLeftUCS.append(len(goalUCS.path()[i].state))
ballsLeftUCS.append(0)

clicksUCS = np.arange(0,len(goalUCS.path()), 1)

plt.xlabel('Click number')
plt.xlabel('Balls left')
plt.title('Evolution of balls left over clicks for UCS')
plt.plot(clicksUCS, ballsLeftUCS)
plt.scatter(clicksUCS, ballsLeftUCS, c='r')

# %%
# DLS
ballsLeftDLS = []
for i in range(len(goalDLS.solution())):
    ballsLeftDLS.append(len(goalDLS.path()[i].state))
ballsLeftDLS.append(0)

clicksDLS = np.arange(0,len(goalDLS.path()), 1)

plt.xlabel('Click number')
plt.xlabel('Balls left')
plt.title('Evolution of balls left over clicks for DLS')
plt.plot(clicksDLS, ballsLeftDLS)
plt.scatter(clicksDLS, ballsLeftDLS, c='r')

# %%
# DLS
ballsLeftIDS = []
for i in range(len(goalIDS.solution())):
    ballsLeftIDS.append(len(goalIDS.path()[i].state))
ballsLeftIDS.append(0)

clicksIDS = np.arange(0,len(goalIDS.path()), 1)

plt.xlabel('Click number')
plt.xlabel('Balls left')
plt.title('Evolution of balls left over clicks for IDS')
plt.plot(clicksIDS, ballsLeftIDS)
plt.scatter(clicksIDS, ballsLeftIDS, c='r')

# %% [markdown]
# # Test 2
# In this test we use a more bigger board and added even more balls. The board to be used is this:
#
# PD: Since some algorithms may not finish, this section will not include metrics.

# %%
size = 6
initial_state = tuple([(0,2),(0,4),(1,0),(1,3),(1,5),(2,1),(2,4),(3,0),(3,2),(3,4),(4,3),(4,5),(5,0),(5,2),(5,4),])

environment = CleanupPuzzleEnvironment(size, size)

for s in initial_state:
    ball = Ball()
    environment.add_thing(ball, s)

print(environment)

# %% [markdown]
# The results are presented as follows:
#
# <u>Using Breath First Search</u>

# %%
initial_state = tuple([(0,2),(0,4),(1,0),(1,3),(1,5),(2,1),(2,4),(3,0),(3,2),(3,4),(4,3),(4,5),(5,0),(5,2),(5,4),])
size = 6

#We sort the position of the balls in the grid. This is for the purpose of correct display.
initial_state = sorted(initial_state, key=lambda x: [x[0], x[1]])
initial_state = tuple(initial_state)

problem = CleanBoardProblem(initial_state, [], size) #We call the method that defines the initial state.
start_time_bfs = time.time() #We initialize the time metric for our search algorithm
goalBFS = breadth_first_search(problem) #We initialize the agent performing a BFS algorithm
end_time_bfs = time.time() - start_time_bfs #We calculate the time it took the algorithm to solve the problem.

#We display the solution of the initial problem
display_solution(goalBFS, initial_state, size)

# %%
<u>Using Depth First Search</u>

# %%
start_time_dfs = time.time() #We initialize the time metric for our search algorithm
goalDFS = depth_first_graph_search(problem) #We initialize the agent performing a BFS algorithm
end_time_dfs = time.time() - start_time_dfs #We calculate the time it took the algorithm to solve the problem.

#We display the solution of the initial problem
display_solution(goalDFS, initial_state, size)

# %% [markdown]
# <u>Using Uniform Cost Search</u>

# %%
start_time_ucs = time.time() #We initialize the time metric for our search algorithm
goalUCS = uniform_cost_search(problem) #We initialize the agent performing a BFS algorithm
end_time_ucs = time.time() - start_time_ucs #We calculate the time it took the algorithm to solve the problem.

#We display the solution of the initial problem
display_solution(goalUCS, initial_state, size)

# %% [markdown]
# <u>Using Depth Limited Search</u>

# %%
start_time_dls = time.time() #We initialize the time metric for our search algorithm
goalDLS = depth_limited_search(problem) #We initialize the agent performing a BFS algorithm
end_time_dls = time.time() - start_time_dls #We calculate the time it took the algorithm to solve the problem.

#We display the solution of the initial problem
display_solution(goalDLS, initial_state, size)

# %%
<u>Using Iterative Deepening Search</u>

# %%
start_time_ids = time.time() #We initialize the time metric for our search algorithm
goalIDS = iterative_deepening_search(problem) #We initialize the agent performing a BFS algorithm
end_time_ids = time.time() - start_time_ids #We calculate the time it took the algorithm to solve the problem.

#We display the solution of the initial problem
display_solution(goalIDS, initial_state, size)

# %% [markdown]
# # Conclusions:
# <ul>
#     <li><b>Could all the search methods solve the problem?</b></li> All the search algorithms can reach the desired goal, as long as we give them enough time to perform all the needed calculations in the case of BFS, and DFS.
#     <li><b>How efficient they were?</b></li> Some of them even looked that they would never reach the goal state, for example, BFS and DFS require much more time to execute big problems than Uniform Cost Search, and even Depth Limited Search could not have ended if it had not been for the limit of 50. But despite of the problems in time and space of Breadth First Search and Uniform Cost Search, those method could find a solution in a few click on the board, while the Depth First Search has the worst time to find the solution and the worst number of clicks on the board until found the solution. Overall, DFS is the worst method in this kind of problem.
#     <li><b>Was it difficult to program the Problem Solving Agent?</b></li> Nope, the only problem was to understand on how represent our states and try to capture that abstract idea inside the logic of the program.
#     <li><b>Which search method overperforms the others?</b></li> The most optimal method was unvariably Uniform Cost Search, and Iterative Deepening Search. It not only determined the correct solution the fastest, but also reached the correct solution in the least amount of clicks. While the amount of clicks was the same for almost all the methods (With one extreme exception, in the form fo DLS), the part that gave the most optimal solution was determined in operating time. UCS and IDS reached a solution in the least amount of time in this case, while other methods, like DFS reached the correct solution, in an absurd amount of time compared to the others.
# </ul>
